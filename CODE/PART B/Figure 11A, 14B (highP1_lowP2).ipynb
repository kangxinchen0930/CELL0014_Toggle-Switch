# %%
# %matplotlib inline
from scipy.integrate import odeint  
import numpy as np
from matplotlib import pyplot as plt
import random
random.seed(12)
from helper_functions import *

# %%
# TEMPLATE TO RUN GILLESPIE SIMULATION OF MODEL

###################
# Helper functions (Do not change!)

def find_index_from_time(t_obs,time,start_index=0):  
    # loop through t_obs array from i=0  
    # stopping when t_obs[i+1] is greater than time  
    # so that t_obs[i] < time < t_obs[i+1]  
    # return i 
    i=start_index
    while i+1<len(t_obs):  
        if t_obs[i+1]>time:
            break
        i=i+1
    # i now stores index corresponding to system at time requested  
    return i 
      
def resample_observations(t_obs_in, s_obs_in, t_obs_out):
    s_obs_out=[] 
    pos=0 
    for time in t_obs_out:  
        i=find_index_from_time(t_obs_in,time, start_index=pos)
        si = s_obs_in[i]  
        s_obs_out.append(si) 
        pos = i
    return s_obs_out


def gen_next_event_time(rate):
    t=random.expovariate(rate)
    return t


def random_choice_from_pdf(pdf):
    cdf=[]
    cumulative_p=0
    for p in pdf:
        cumulative_p+=p
        cdf.append(cumulative_p)
    rand=random.random()

    for i in range(len(cdf)):
        if rand<cdf[i]:
            return i
    # last cdf should be 1.0 so the following should never happen!
    print("Error generating choice, check PDF")
    return None

# %%
# define stochastic function
def gillespie_gene_exp(s0,t_obs_out,params):

    #Unpack parameters and species variables
    M1, M2, P1, P2 = s0
    km1, km2, kdm1, kdm2, kp1, kp2, kdp1, kdp2, K1, K2, n1, n2 = params

    # create arrays for output
    s_obs=[]
    t_obs=[]

    # read in start time and end time
    t_init=t_obs_out[0]
    t_final=t_obs_out[-1]

    t=t_init
    t_obs.append(t)
    s_obs.append(s0)

    while t < t_final:

        # labels for each event type
        
        types=['M1', 'M2', 'M1_to_P1', 'M2_to_P2', 'M1_to_0','M2_to_0','P1_to_0','P2_to_0']

        # http://localhost:8888/notebooks/Week%2010/stochastic_lowP1highP2.ipynb#rate expressions for each of the events
        
        rate_M1 = km1 * ((K2**n2)/(P2**n2 + K2**n2)) 
        rate_M2 = km2 * ((K1**n1)/(P1**n1 + K1**n1))
        rate_M1_to_P1 = kp1 * M1
        rate_M2_to_P2 = kp2 * M2
        rate_M1_to_0 = kdm1*M1
        rate_M2_to_0 = kdm2*M2
        rate_P1_to_0 = kdp1*P1
        rate_P2_to_0 = kdp2*P2
        
        # store the rates into a list
        
        rates=[rate_M1, rate_M2, rate_M1_to_P1, rate_M2_to_P2, rate_M1_to_0, 
               rate_M2_to_0, rate_P1_to_0, rate_P2_to_0]

        ## CARRY OUT GILLESPIE ALGORITHM TO STEP FORWARD TO NEXT EVENT
        ## AND UPDATE SYSTEM STATE ACCORDING TO EVENT TYPE

        # calc total reaction rate
        rate_all_events=sum(rates)

        # if rate of events is zero break from loop
        # e.g. when all reactants used up
        if rate_all_events==0:
            break

        # generate the time until the next event
        # in accordance with rate_all_events
        next_event=gen_next_event_time(rate_all_events)

        # calc PDF for event type
        # in accordance with relative rates
        pdf=[]
        for event_rate in rates:
            p_event = event_rate/sum(rates)
            pdf.append(p_event)

        rand_i =  random_choice_from_pdf(pdf)
        event_type=types[rand_i]

        # increment time and number of molecules
        # according to event type
        t=t+next_event

        #-----------------------------------#

        ## ALGORITHM HAS INCREMENTED TIME AND SELECTED NEXT EVENT
        ## WE NOW NEED TO UPDATE OUR SYSTEM ACCORDING TO THE EVENT
        ## TYPE STORED IN VARIABLE event_type

        # if-elif-else commands to update the system
        
        # types=['M1', 'M2', 'M1_to_P1', 'M2_to_P2', 'M1_to_0','M2_to_0','P1_to_0','P2_to_0', ]
        
        if event_type=='M1':
            M1+=1
        elif event_type=='M2':
            M2+=1
        elif event_type=='M1_to_P1':
            P1+=1
        elif event_type=='M2_to_P2':
            P2+=1
        elif event_type=='M1_to_0':
            M1-=1
        elif event_type=='M2_to_0':
            M2-=1
        elif event_type=='P1_to_0':
            P1-=1
        elif event_type=='P2_to_0':
            P2-=1
        else:
            print("error unknown event type!!")

        # store observation of all species in model for observation
        
        s0= M1,M2,P1,P2
        
        t_obs.append(t)
        s_obs.append(s0)

        # loops until time t exceeds t_final

    # loop has ended

    # before we return the results we must
    # resample the output to provide observations in accordance
    # with the t_obs passed to the function
    s_obs_out=resample_observations(t_obs,s_obs,t_obs_out)
    return np.array(s_obs_out)

# %%
# Figure 11A: Plot of the stochastic system behaviour over time  

# Set initial conditions and parameters
M1=0.0
M2=0.0
P1=1000
P2=100

#params
kp1= 0.9726
kp2= 1.170
kdp1 = 0.0165
kdp2 = 0.0165
K1 = 31.94
K2 = 30.0
n1 = 2.0
n2 = 2.0
km1= 8.3
km2= 2.06
kdm1 = 0.1386
kdm2 = 0.1386

s0=(M1,M2,P1,P2)
params = (km1, km2, kdm1, kdm2, kp1, kp2, kdp1, kdp2, K1, K2, n1, n2)

t_max=1000
t_obs=np.linspace(0,t_max,t_max+1)

# Run simulation of the model
s_obs=gillespie_gene_exp(s0,t_obs,params)

M1_obs=s_obs[:,0]
M2_obs=s_obs[:,1]
P1_obs=s_obs[:,2]
P2_obs=s_obs[:,3]

# Plot results 

fig = plt.figure(figsize=(10,10))
fig.suptitle('Single simulation of the Stochastic Genetic Toggle Switch model over time', 
              fontsize=15, fontweight='bold', y=0.98)
ax1=fig.add_subplot(2,1,1)
ax2=fig.add_subplot(2,1,2)

ax1.set_ylabel('#mRNA copies')
ax2.set_ylabel('#Protein copies')
ax2.set_xlabel('Time (mins)')

ax1.plot(t_obs, M1_obs, 'g-', label ='M1')
ax1.plot(t_obs, M2_obs, 'm-', label ='M2')
ax2.plot(t_obs, P1_obs, 'b-', label ='P1')
ax2.plot(t_obs, P2_obs, 'r-', label ='P2')

ax1.set_ylim(-1,100)
ax2.set_ylim(-50,5000)

ax1.legend(loc = 1, prop={'size': 15}, shadow=True)
ax2.legend(loc = 1, prop={'size': 15}, shadow=True)

ax1.xaxis.label.set_size(15)
ax1.yaxis.label.set_size(15)
ax1.xaxis.set_tick_params(labelsize=15)
ax1.yaxis.set_tick_params(labelsize=15)
ax2.xaxis.label.set_size(15)
ax2.yaxis.label.set_size(15)
ax2.xaxis.set_tick_params(labelsize=15)
ax2.yaxis.set_tick_params(labelsize=15)

plt.savefig('fig11A.png');

# %%
# Figure 12 and 13

# DEFINE INITIAL CONDITIONS AND PARAMETERS
M1=0.0
M2=0.0
P1=1000
P2=100

kp1= 0.9726
kp2= 1.170
kdp1 = 0.0165
kdp2 = 0.0165
K1 = 31.94
K2 = 30.0
n1 = 2.0
n2 = 2.0
km1= 8.3
km2= 2.06
kdm1 = 0.1386
kdm2 = 0.1386

s0 = (M1,M2,P1,P2)
params = (km1, km2, kdm1, kdm2, kp1, kp2, kdp1, kdp2, K1, K2, n1, n2)

t_max = 1000
t_obs=np.linspace(0,t_max,t_max+1)

# RUN SIMULATIONS
#n_runs = 200
n_runs = 5
M1_runs=[]
M2_runs=[]
P1_runs=[]
P2_runs=[]

for i in range(n_runs):
    print("Simulating {} of {} runs...".format(i+1,n_runs))
    s_obs=gillespie_gene_exp(s0,t_obs,params)
    
    M1_obs=s_obs[:,0]
    M2_obs=s_obs[:,1]
    P1_obs=s_obs[:,2]
    P2_obs=s_obs[:,3]
    
    M1_runs.append(M1_obs)
    M2_runs.append(M2_obs)
    P1_runs.append(P1_obs)
    P2_runs.append(P2_obs)

M1_runs = np.array(M1_runs)
M2_runs = np.array(M2_runs)
P1_runs = np.array(P1_runs)
P2_runs = np.array(P2_runs)
# Out:
# Simulating 1 of 5 runs...
# Simulating 2 of 5 runs...
# Simulating 3 of 5 runs...
# Simulating 4 of 5 runs...
# Simulating 5 of 5 runs...

# %%
# Plot results
fig_runs=plt.figure(figsize=(10,10))
fig_runs.suptitle('Simulation of the Stochastic Genetic Toggle Switch model', 
              fontsize=15, fontweight='bold', y=0.93)
ax1=fig_runs.add_subplot(2,1,1)
ax2=fig_runs.add_subplot(2,1,2)

ax1.plot(t_obs, M1_runs.T,'tab:cyan')
ax1.plot(t_obs, M2_runs.T,'tab:gray')
ax2.plot(t_obs, P1_runs.T,'tab:cyan')
ax2.plot(t_obs, P2_runs.T,'tab:gray')

# Plot the average trendline
av_M1 = np.average(M1_runs, axis=0)
ax1.plot(t_obs, av_M1,'k-', label='Average M1')
av_M2 = np.average(M2_runs, axis=0)
ax1.plot(t_obs, av_M2,'m-',label='Average M2')

av_P1 = np.average(P1_runs, axis=0)
ax2.plot(t_obs, av_P1,'b-',label='Average P1')
av_P2 = np.average(P2_runs, axis=0)
ax2.plot(t_obs, av_P2,'r-',label='Average P2')

# Adjust labels
ax1.set_ylabel('#mRNA copies')
ax2.set_ylabel('#Protein copies')
ax2.set_xlabel('Time (mins)')

ax1.set_ylim(-4,100)
ax2.set_ylim(-100,5000)

ax1.legend(loc = 1, prop={'size': 15}, shadow=True)
ax2.legend(loc = 1, prop={'size': 15}, shadow=True)

ax1.xaxis.label.set_size(15)
ax1.yaxis.label.set_size(15)
ax1.xaxis.set_tick_params(labelsize=15)
ax1.yaxis.set_tick_params(labelsize=15)
ax2.xaxis.label.set_size(15)
ax2.yaxis.label.set_size(15)
ax2.xaxis.set_tick_params(labelsize=15)
ax2.yaxis.set_tick_params(labelsize=15)

plt.savefig('fig12_highP1.png');
#plt.savefig('fig13_highP1.png');

# %%
# DEFINE INITIAL CONDITIONS AND PARAMETERS
M1=0.0
M2=0.0
P1=1000
P2=100

kp1= 0.9726
kp2= 1.170
kdp1 = 0.0165
kdp2 = 0.0165
K1 = 31.94
K2 = 30.0
n1 = 2.0
n2 = 2.0
km1= 8.3
km2= 2.06
kdm1 = 0.1386
kdm2 = 0.1386

s0 = (M1,M2,P1,P2)
params = (km1, km2, kdm1, kdm2, kp1, kp2, kdp1, kdp2, K1, K2, n1, n2)

t_max = 6000
t_obs=np.linspace(0,t_max,t_max+1)

# RUN SIMULATIONS
n_runs = 200
M1_runs=[]
M2_runs=[]
P1_runs=[]
P2_runs=[]

for i in range(n_runs):
    print("Simulating {} of {} runs...".format(i+1,n_runs))
    s_obs=gillespie_gene_exp(s0,t_obs,params)
    
    M1_obs=s_obs[:,0]
    M2_obs=s_obs[:,1]
    P1_obs=s_obs[:,2]
    P2_obs=s_obs[:,3]
    
    M1_runs.append(M1_obs)
    M2_runs.append(M2_obs)
    P1_runs.append(P1_obs)
    P2_runs.append(P2_obs)

M1_runs = np.array(M1_runs)
M2_runs = np.array(M2_runs)
P1_runs = np.array(P1_runs)
P2_runs = np.array(P2_runs);
# Out:
# Simulating 1 of 200 runs...
# Simulating 2 of 200 runs...
# Simulating 3 of 200 runs...
# Simulating 4 of 200 runs...
# Simulating 5 of 200 runs...
# Simulating 6 of 200 runs...
# Simulating 7 of 200 runs...
# Simulating 8 of 200 runs...
# Simulating 9 of 200 runs...
# Simulating 10 of 200 runs...
# Simulating 11 of 200 runs...
# Simulating 12 of 200 runs...
# Simulating 13 of 200 runs...
# Simulating 14 of 200 runs...
# Simulating 15 of 200 runs...
# Simulating 16 of 200 runs...
# Simulating 17 of 200 runs...
# Simulating 18 of 200 runs...
# Simulating 19 of 200 runs...
# Simulating 20 of 200 runs...
# Simulating 21 of 200 runs...
# Simulating 22 of 200 runs...
# Simulating 23 of 200 runs...
# Simulating 24 of 200 runs...
# Simulating 25 of 200 runs...
# Simulating 26 of 200 runs...
# Simulating 27 of 200 runs...
# Simulating 28 of 200 runs...
# Simulating 29 of 200 runs...
# Simulating 30 of 200 runs...
# Simulating 31 of 200 runs...
# Simulating 32 of 200 runs...
# Simulating 33 of 200 runs...
# Simulating 34 of 200 runs...
# Simulating 35 of 200 runs...
# Simulating 36 of 200 runs...
# Simulating 37 of 200 runs...
# Simulating 38 of 200 runs...
# Simulating 39 of 200 runs...
# Simulating 40 of 200 runs...
# Simulating 41 of 200 runs...
# Simulating 42 of 200 runs...
# Simulating 43 of 200 runs...
# Simulating 44 of 200 runs...
# Simulating 45 of 200 runs...
# Simulating 46 of 200 runs...
# Simulating 47 of 200 runs...
# Simulating 48 of 200 runs...
# Simulating 49 of 200 runs...
# Simulating 50 of 200 runs...
# Simulating 51 of 200 runs...
# Simulating 52 of 200 runs...
# Simulating 53 of 200 runs...
# Simulating 54 of 200 runs...
# Simulating 55 of 200 runs...
# Simulating 56 of 200 runs...
# Simulating 57 of 200 runs...
# Simulating 58 of 200 runs...
# Simulating 59 of 200 runs...
# Simulating 60 of 200 runs...
# Simulating 61 of 200 runs...
# Simulating 62 of 200 runs...
# Simulating 63 of 200 runs...
# Simulating 64 of 200 runs...
# Simulating 65 of 200 runs...
# Simulating 66 of 200 runs...
# Simulating 67 of 200 runs...
# Simulating 68 of 200 runs...
# Simulating 69 of 200 runs...
# Simulating 70 of 200 runs...
# Simulating 71 of 200 runs...
# Simulating 72 of 200 runs...
# Simulating 73 of 200 runs...
# Simulating 74 of 200 runs...
# Simulating 75 of 200 runs...
# Simulating 76 of 200 runs...
# Simulating 77 of 200 runs...
# Simulating 78 of 200 runs...
# Simulating 79 of 200 runs...
# Simulating 80 of 200 runs...
# Simulating 81 of 200 runs...
# Simulating 82 of 200 runs...
# Simulating 83 of 200 runs...
# Simulating 84 of 200 runs...
# Simulating 85 of 200 runs...
# Simulating 86 of 200 runs...
# Simulating 87 of 200 runs...
# Simulating 88 of 200 runs...
# Simulating 89 of 200 runs...
# Simulating 90 of 200 runs...
# Simulating 91 of 200 runs...
# Simulating 92 of 200 runs...
# Simulating 93 of 200 runs...
# Simulating 94 of 200 runs...
# Simulating 95 of 200 runs...
# Simulating 96 of 200 runs...
# Simulating 97 of 200 runs...
# Simulating 98 of 200 runs...
# Simulating 99 of 200 runs...
# Simulating 100 of 200 runs...
# Simulating 101 of 200 runs...
# Simulating 102 of 200 runs...
# Simulating 103 of 200 runs...
# Simulating 104 of 200 runs...
# Simulating 105 of 200 runs...
# Simulating 106 of 200 runs...
# Simulating 107 of 200 runs...
# Simulating 108 of 200 runs...
# Simulating 109 of 200 runs...
# Simulating 110 of 200 runs...
# Simulating 111 of 200 runs...
# Simulating 112 of 200 runs...
# Simulating 113 of 200 runs...
# Simulating 114 of 200 runs...
# Simulating 115 of 200 runs...
# Simulating 116 of 200 runs...
# Simulating 117 of 200 runs...
# Simulating 118 of 200 runs...
# Simulating 119 of 200 runs...
# Simulating 120 of 200 runs...
# Simulating 121 of 200 runs...
# Simulating 122 of 200 runs...
# Simulating 123 of 200 runs...
# Simulating 124 of 200 runs...
# Simulating 125 of 200 runs...
# Simulating 126 of 200 runs...
# Simulating 127 of 200 runs...
# Simulating 128 of 200 runs...
# Simulating 129 of 200 runs...
# Simulating 130 of 200 runs...
# Simulating 131 of 200 runs...
# Simulating 132 of 200 runs...
# Simulating 133 of 200 runs...
# Simulating 134 of 200 runs...
# Simulating 135 of 200 runs...
# Simulating 136 of 200 runs...
# Simulating 137 of 200 runs...
# Simulating 138 of 200 runs...
# Simulating 139 of 200 runs...
# Simulating 140 of 200 runs...
# Simulating 141 of 200 runs...
# Simulating 142 of 200 runs...
# Simulating 143 of 200 runs...
# Simulating 144 of 200 runs...
# Simulating 145 of 200 runs...
# Simulating 146 of 200 runs...
# Simulating 147 of 200 runs...
# Simulating 148 of 200 runs...
# Simulating 149 of 200 runs...
# Simulating 150 of 200 runs...
# Simulating 151 of 200 runs...
# Simulating 152 of 200 runs...
# Simulating 153 of 200 runs...
# Simulating 154 of 200 runs...
# Simulating 155 of 200 runs...
# Simulating 156 of 200 runs...
# Simulating 157 of 200 runs...
# Simulating 158 of 200 runs...
# Simulating 159 of 200 runs...
# Simulating 160 of 200 runs...
# Simulating 161 of 200 runs...
# Simulating 162 of 200 runs...
# Simulating 163 of 200 runs...
# Simulating 164 of 200 runs...
# Simulating 165 of 200 runs...
# Simulating 166 of 200 runs...
# Simulating 167 of 200 runs...
# Simulating 168 of 200 runs...
# Simulating 169 of 200 runs...
# Simulating 170 of 200 runs...
# Simulating 171 of 200 runs...
# Simulating 172 of 200 runs...
# Simulating 173 of 200 runs...
# Simulating 174 of 200 runs...
# Simulating 175 of 200 runs...
# Simulating 176 of 200 runs...
# Simulating 177 of 200 runs...
# Simulating 178 of 200 runs...
# Simulating 179 of 200 runs...
# Simulating 180 of 200 runs...
# Simulating 181 of 200 runs...
# Simulating 182 of 200 runs...
# Simulating 183 of 200 runs...
# Simulating 184 of 200 runs...
# Simulating 185 of 200 runs...
# Simulating 186 of 200 runs...
# Simulating 187 of 200 runs...
# Simulating 188 of 200 runs...
# Simulating 189 of 200 runs...
# Simulating 190 of 200 runs...
# Simulating 191 of 200 runs...
# Simulating 192 of 200 runs...
# Simulating 193 of 200 runs...
# Simulating 194 of 200 runs...
# Simulating 195 of 200 runs...
# Simulating 196 of 200 runs...
# Simulating 197 of 200 runs...
# Simulating 198 of 200 runs...
# Simulating 199 of 200 runs...
# Simulating 200 of 200 runs...

# %%
#calculate CV = sd/mean

std_m1 = np.std(M1_runs)
std_m2 = np.std(M2_runs)
std_p1 = np.std(P1_runs)
std_p2 = np.std(P2_runs)

mean_m1 = np.mean(M1_runs)
mean_m2 = np.mean(M2_runs)
mean_p1 = np.mean(P1_runs)
mean_p2 = np.mean(P2_runs)

cv_m1 = std_m1/mean_m1
cv_m2 = std_m2/mean_m2
cv_p1 = std_p1/mean_p1
cv_p2 = std_p2/mean_p2

max_m1 = np.max(M1_runs)
max_m2 = np.max(M2_runs)
max_p1 = np.max(P1_runs)
max_p2 = np.max(P2_runs)

print(f"Standard deviation of M1 is {std_m1:.2f}, M2 is {std_m2:.2f}, P1 is {std_p1:.2f} and P2 is {std_p2:.2f}.")
print(f"Mean of M1 is {mean_m1:.2f}, M2 is {mean_m2:.2f}, P1 is {mean_p1:.2f} and P2 is {mean_p2:.2f}.")
print(f"CV of M1 is {cv_m1:.2f}, M2 is {cv_m2:.2f}, P1 is {cv_p1:.2f} and P2 is {cv_p2:.2f}.")

print(max_m1)
print(max_m2)
print(max_p1)
print(max_p2)
# Out:
# Standard deviation of M1 is 9.62, M2 is 0.04, P1 is 422.30 and P2 is 7.27.
# Mean of M1 is 59.01, M2 is 0.00, P1 is 3452.96 and P2 is 1.14.
# CV of M1 is 0.16, M2 is 24.07, P1 is 0.12 and P2 is 6.37.
# 102.0
# 2.0
# 4323.0
# 103.0

# %%
# Figure 14B
# Plot histogram

fig_hist=plt.figure(figsize=(20,20))
fig_hist.suptitle('Histogram of the frequencies of the final protein levels\n (stochastic model, 200 runs)', fontsize=25, fontweight='bold', y=0.95)

ax1=fig_hist.add_subplot(2,1,1)
ax2=fig_hist.add_subplot(2,1,2)

ax1.hist(M1_runs.T[-1],bins=np.arange(0,100,2), color = 'green', label='M1')
ax1.hist(M2_runs.T[-1],bins=np.arange(0,100,2), color = 'gray', label = 'M2')
ax2.hist(P1_runs.T[-1],bins=np.arange(0,4000,100), color = 'blue', label='P1')
ax2.hist(P2_runs.T[-1],bins=np.arange(0,4000,100), color = 'green', label='P2')

ax1.axvline(mean_m1, color='k', linestyle='dashed', linewidth=5)
ax1.axvline(mean_m2, color='k', linestyle='dashed', linewidth=5)
ax2.axvline(mean_p1, color='k', linestyle='dashed', linewidth=5)
ax2.axvline(mean_p2, color='k', linestyle='dashed', linewidth=5)

ax1.set_xlabel('#mRNA copies')
ax2.set_xlabel('#Protein copies')
ax1.set_ylabel('Frequency')
ax2.set_ylabel('Frequency')

ax1.legend(loc = 1, prop={'size': 25}, shadow=True)
ax2.legend(loc = 1, prop={'size': 25}, shadow=True)
ax1.xaxis.label.set_size(25)
ax1.yaxis.label.set_size(25)
ax1.xaxis.set_tick_params(labelsize=25)
ax1.yaxis.set_tick_params(labelsize=25)
ax2.xaxis.label.set_size(25)
ax2.yaxis.label.set_size(25)
ax2.xaxis.set_tick_params(labelsize=25)
ax2.yaxis.set_tick_params(labelsize=25)

plt.savefig('fig14B.png');

# %%
# Plot of the stochastic system behaviour over extended period of time  

# Set initial conditions and parameters
M1=0.0
M2=0.0
P1=100
P2=1000

# params
kp1= 0.9726
kp2= 1.170
kdp1 = 0.0165
kdp2 = 0.0165
K1 = 31.94
K2 = 30.0
n1 = 2.0
n2 = 2.0
km1= 8.3
km2= 2.06
kdm1 = 0.1386
kdm2 = 0.1386

s0=(M1,M2,P1,P2)
params = (km1, km2, kdm1, kdm2, kp1, kp2, kdp1, kdp2, K1, K2, n1, n2)

t_max= 25000
t_obs=np.linspace(0,t_max,t_max+1)

# Run simulation of the model
s_obs=gillespie_gene_exp(s0,t_obs,params)

M1_obs=s_obs[:,0]
M2_obs=s_obs[:,1]
P1_obs=s_obs[:,2]
P2_obs=s_obs[:,3]

# Plot results 

fig = plt.figure(figsize=(10,10))
fig.suptitle('Single simulation of the Stochastic Genetic Toggle Switch model over extended period of time', 
              fontsize=15, fontweight='bold', y=0.98)
ax1=fig.add_subplot(2,1,1)
ax2=fig.add_subplot(2,1,2)

ax1.set_ylabel('#mRNA copies')
ax2.set_ylabel('#Protein copies')
ax2.set_xlabel('Time (mins)')

ax1.plot(t_obs, M1_obs, 'g-', label ='M1')
ax1.plot(t_obs, M2_obs, 'm-', label ='M2')
ax2.plot(t_obs, P1_obs, 'b-', label ='P1')
ax2.plot(t_obs, P2_obs, 'r-', label ='P2')

ax1.set_ylim(-1,30)
ax2.set_ylim(-50,1750)

ax1.legend(loc = 1, prop={'size': 15}, shadow=True)
ax2.legend(loc = 1, prop={'size': 15}, shadow=True)

ax1.xaxis.label.set_size(15)
ax1.yaxis.label.set_size(15)
ax1.xaxis.set_tick_params(labelsize=15)
ax1.yaxis.set_tick_params(labelsize=15)
ax2.xaxis.label.set_size(15)
ax2.yaxis.label.set_size(15)
ax2.xaxis.set_tick_params(labelsize=15)
ax2.yaxis.set_tick_params(labelsize=15)

plt.savefig('extendedstochasticplot.png');

# %%
# Phase plot

fig = plt.figure(figsize=(20,20))
fig.suptitle('Phase plot of the stochastic simulation (highP1/lowP2)', fontsize=25, fontweight='bold', y=0.95)
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)

ax1.plot(M1_runs[0], M2_runs[0])
ax2.plot(P1_runs[0], P2_runs[0])

ax1.set_xlabel('#mRNA1 copies')
ax1.set_ylabel('#mRNA2 copies')
ax2.set_xlabel('#P1 copies')
ax2.set_ylabel('#P2 copies')

ax1.xaxis.label.set_size(25)
ax1.yaxis.label.set_size(25)
ax1.xaxis.set_tick_params(labelsize=25)
ax1.yaxis.set_tick_params(labelsize=25)
ax2.xaxis.label.set_size(25)
ax2.yaxis.label.set_size(25)
ax2.xaxis.set_tick_params(labelsize=25)
ax2.yaxis.set_tick_params(labelsize=25)

plt.savefig('stochasticphaseplot_P1high.png');
